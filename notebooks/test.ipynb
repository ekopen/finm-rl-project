# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("/Users/nickdonato/finm-rl-project").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from experiments.common import load_spy_splits, make_single_asset_env, make_base_config, train_env_with_config
from ppo.eval_utils import run_policy_episode
from ppo.ppo_agent import PPOAgent
import numpy as np

train_df, _, test_df = load_spy_splits()
train_env = make_single_asset_env(train_df)
config = make_base_config(epochs=5)  # shorter for debug
agent = train_env_with_config(train_env, config)

test_env = make_single_asset_env(test_df)
state = test_env.reset()

actions = []
for _ in range(500):  # sample first 500 steps
    a, lp, v = agent.act(state)
    actions.append(a)
    state, r, done, info = test_env.step(a)
    if done:
        break

actions = np.array(actions)
print("Action counts:", {i: (actions == i).sum() for i in range(3)})
# Out:
# Downloading data for SPY...
# /Users/nickdonato/finm-rl-project/data/data_loader.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# [epoch 1/5] mean_reward=-0.000471, policy_loss=-0.0654, value_loss=0.0578, entropy=0.5748, approx_kl=0.002922
# [epoch 2/5] mean_reward=-0.000405, policy_loss=0.0884, value_loss=0.0562, entropy=0.5572, approx_kl=0.000325
# [epoch 4/5] mean_reward=-0.000511, policy_loss=0.0614, value_loss=0.0643, entropy=0.4896, approx_kl=0.000000
# [epoch 5/5] mean_reward=-0.000404, policy_loss=0.0206, value_loss=0.0163, entropy=0.4941, approx_kl=0.000000
# Action counts: {0: np.int64(496), 1: np.int64(4), 2: np.int64(0)}
